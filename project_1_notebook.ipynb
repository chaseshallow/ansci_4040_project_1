# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ------------ --------------------------- 3.1/10.0 MB 20.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.0 MB 29.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 26.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---------------- ----------------------- 5.2/12.7 MB 37.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.7 MB 37.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.7 MB 37.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.7 MB 37.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.7 MB 37.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.7 MB 37.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.7 MB 37.1 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("project_1_ANSC_4040_dataset.csv")
data.head()
# Out:
# C:\Users\cra74\AppData\Local\Temp\ipykernel_24648\419717886.py:1: DtypeWarning: Columns (0: ReproductionStatus) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("project_1_ANSC_4040_dataset.csv")
#    AnimalNumber  LactationNumber  DaysInMilk ReproductionStatus  Avgmilkflow  \
# 0       31317.0              2.0       255.0           Pregnant     2.812273
# 1       60614.0              1.0       251.0           Pregnant     2.902991
# 2       36947.0              1.0       183.0           Pregnant     3.401943
# 3       31720.0              2.0        82.0               Bred     4.309128
# 4       23630.0              6.0       182.0           Pregnant     3.719457
#
#    Flow30_60Session  YieldFirst2Min_Session  YieldSession  \
# 0          2.898455                5.874021      8.028585
# 1          3.801104                6.372973      7.030682
# 2          3.701314                7.048825     16.374685
# ...
